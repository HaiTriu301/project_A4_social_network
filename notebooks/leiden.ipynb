# %%
import pandas as pd
df = pd.read_csv(r"D:\Study\HK6\Social Network\Project\code - Copy - Copy\outputs\communities\leiden_communities.csv")
print(df['community_id'].value_counts())
# Out:
# community_id
# 0     5668
# 1     2991
# 2     2547
# 3     2431
# 4     2245
# 5     2177
# 6     2152
# 7     2137
# 8     1919
# 9     1689
# 10    1360
# 11    1351
# 12    1315
# 13    1304
# 14    1198
# 15    1166
# 16    1083
# 17     970
# 18     881
# 19     756
# 21       4
# 20       4
# 23       3
# 22       3
# 26       2
# 27       2
# 34       2
# 25       2
# 29       2
# 28       2
# 30       2
# 31       2
# 33       2
# 32       2
# 24       2
# 35       2
# Name: count, dtype: int64
